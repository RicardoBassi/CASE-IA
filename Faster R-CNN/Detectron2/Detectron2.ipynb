# %%
import torch, torchvision
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
# from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from detectron2.data.catalog import DatasetCatalog

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import torch, torchvision
#       2 # You may need to restart your runtime prior to this, to let your installation take effect
#       3 # Some basic setup:
#       4 # Setup detectron2 logger
# ----> 5 import detectron2
#       6 from detectron2.utils.logger import setup_logger
#       7 setup_logger()
#
# ModuleNotFoundError: No module named 'detectron2'

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("my_dataset_train", {}, "../DatasetMouse/Computer mouse/train/_annotations.coco.json", "../DatasetMouse/Computer mouse/train")
register_coco_instances("my_dataset_val", {}, "../DatasetMouse/Computer mouse/valid/_annotations.coco.json", "../DatasetMouse/Computer mouse/valid")
register_coco_instances("my_dataset_test", {}, "../DatasetMouse/Computer mouse/test/_annotations.coco.json", "../DatasetMouse/Computer mouse/test")

# %%
#visualize training data
my_dataset_train_metadata = MetadataCatalog.get("my_dataset_train")
dataset_dicts = DatasetCatalog.get("my_dataset_train")

import random
from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=my_dataset_train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
# Out:
# WARNING [01/24 20:07:48 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/24 20:07:48 d2.data.datasets.coco]: Loaded 140 images in COCO format from ../DatasetMouse/Computer mouse/train/_annotations.coco.json

# %%
#We are importing our own Trainer Module here to use the COCO validation evaluation during training. Otherwise no validation eval occurs.

from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator

class CocoTrainer(DefaultTrainer):

  @classmethod
  def build_evaluator(cls, cfg, dataset_name, output_folder=None):

    if output_folder is None:
        os.makedirs("coco_eval", exist_ok=True)
        output_folder = "coco_eval"

    return COCOEvaluator(dataset_name, cfg, False, output_folder)

# %%
#from .detectron2.tools.train_net import Trainer
#from detectron2.engine import DefaultTrainer
# select from modelzoo here: https://github.com/facebookresearch/detectron2/blob/master/MODEL_ZOO.md#coco-object-detection-baselines

from detectron2.config import get_cfg
#from detectron2.evaluation.coco_evaluation import COCOEvaluator
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_dataset_train",)
cfg.DATASETS.TEST = ("my_dataset_val",)

cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.001


cfg.SOLVER.WARMUP_ITERS = 1000
cfg.SOLVER.MAX_ITER = 300 #adjust up if val mAP is still rising, adjust down if overfit
cfg.SOLVER.STEPS = (1000, 1500)
cfg.SOLVER.GAMMA = 0.05


cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 64
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2 #your number of classes + 1

cfg.TEST.EVAL_PERIOD = 500


os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = CocoTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [01/24 20:11:22 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
# )
# WARNING [01/24 20:11:22 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/24 20:11:22 d2.data.datasets.coco]: Loaded 140 images in COCO format from ../DatasetMouse/Computer mouse/train/_annotations.coco.json
# [01/24 20:11:22 d2.data.build]: Removed 0 images with no usable annotations. 140 images left.
# [01/24 20:11:22 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [01/24 20:11:22 d2.data.build]: Using training sampler TrainingSampler
# [01/24 20:11:22 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/24 20:11:22 d2.data.common]: Serializing 140 elements to byte tensors and concatenating them all ...
# [01/24 20:11:22 d2.data.common]: Serialized dataset takes 0.04 MiB
# [01/24 20:11:22 d2.data.build]: Making batched data loader with batch_size=4
# WARNING [01/24 20:11:22 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [01/24 20:11:22 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x/139173657/model_final_68b088.pkl ...
# model_final_68b088.pkl: 421MB [00:17, 23.7MB/s]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (5, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (5,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (16, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (16,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [01/24 20:11:40 d2.engine.train_loop]: Starting training from iteration 0
# b:\Programas\Anaconda\envs\prova\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3527.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [01/24 20:32:01 d2.utils.events]:  eta: 5:14:49  iter: 19  total_loss: 2.482  loss_cls: 1.631  loss_box_reg: 0.8929  loss_rpn_cls: 0.0131  loss_rpn_loc: 0.003813    time: 62.3843  last_time: 40.0470  data_time: 0.4875  last_data_time: 0.0093   lr: 6.427e-05  max_mem: 7672M
# WARNING:tensorflow:From b:\Programas\Anaconda\envs\prova\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# [01/24 20:57:12 d2.utils.events]:  eta: 5:03:23  iter: 39  total_loss: 1.419  loss_cls: 0.5995  loss_box_reg: 0.8459  loss_rpn_cls: 0.005788  loss_rpn_loc: 0.004208    time: 68.8718  last_time: 64.3750  data_time: 0.0082  last_data_time: 0.0375   lr: 0.00013087  max_mem: 7672M
# [01/24 21:19:11 d2.utils.events]:  eta: 4:46:56  iter: 59  total_loss: 1.066  loss_cls: 0.2429  loss_box_reg: 0.7872  loss_rpn_cls: 0.004949  loss_rpn_loc: 0.002578    time: 67.8589  last_time: 37.9215  data_time: 0.0069  last_data_time: 0.0043   lr: 0.00019747  max_mem: 7672M
# [01/24 21:41:23 d2.utils.events]:  eta: 4:16:42  iter: 79  total_loss: 0.8166  loss_cls: 0.1306  loss_box_reg: 0.6618  loss_rpn_cls: 0.004742  loss_rpn_loc: 0.003664    time: 67.5371  last_time: 28.9996  data_time: 0.0086  last_data_time: 0.0035   lr: 0.00026407  max_mem: 7672M
# [01/24 21:59:00 d2.utils.events]:  eta: 3:35:06  iter: 99  total_loss: 0.4581  loss_cls: 0.07979  loss_box_reg: 0.3749  loss_rpn_cls: 0.004168  loss_rpn_loc: 0.005577    time: 64.5390  last_time: 37.5400  data_time: 0.0056  last_data_time: 0.0057   lr: 0.00033067  max_mem: 7672M
# [01/24 22:22:40 d2.utils.events]:  eta: 3:17:04  iter: 119  total_loss: 0.3144  loss_cls: 0.06685  loss_box_reg: 0.2357  loss_rpn_cls: 0.003289  loss_rpn_loc: 0.00345    time: 65.6297  last_time: 43.7816  data_time: 0.0075  last_data_time: 0.0333   lr: 0.00039727  max_mem: 7672M
# [01/24 22:42:26 d2.utils.events]:  eta: 2:50:19  iter: 139  total_loss: 0.3221  loss_cls: 0.07167  loss_box_reg: 0.2432  loss_rpn_cls: 0.0009837  loss_rpn_loc: 0.004421    time: 64.7152  last_time: 28.4180  data_time: 0.0068  last_data_time: 0.0052   lr: 0.00046387  max_mem: 7672M
# [01/24 22:58:25 d2.utils.events]:  eta: 2:21:13  iter: 159  total_loss: 0.2547  loss_cls: 0.06025  loss_box_reg: 0.1925  loss_rpn_cls: 0.0006493  loss_rpn_loc: 0.002523    time: 62.5905  last_time: 58.7464  data_time: 0.0043  last_data_time: 0.0053   lr: 0.00053047  max_mem: 7672M
# [01/24 23:15:19 d2.utils.events]:  eta: 1:59:59  iter: 179  total_loss: 0.2319  loss_cls: 0.05464  loss_box_reg: 0.1776  loss_rpn_cls: 0.0007438  loss_rpn_loc: 0.002432    time: 61.2561  last_time: 97.1928  data_time: 0.0045  last_data_time: 0.0062   lr: 0.00059707  max_mem: 7672M
# [01/24 23:30:45 d2.utils.events]:  eta: 1:39:36  iter: 199  total_loss: 0.2423  loss_cls: 0.04462  loss_box_reg: 0.1899  loss_rpn_cls: 0.0005652  loss_rpn_loc: 0.002575    time: 59.7420  last_time: 52.2088  data_time: 0.0051  last_data_time: 0.0029   lr: 0.00066367  max_mem: 7672M
# [01/24 23:47:22 d2.utils.events]:  eta: 1:19:30  iter: 219  total_loss: 0.2173  loss_cls: 0.04139  loss_box_reg: 0.1695  loss_rpn_cls: 0.0004978  loss_rpn_loc: 0.002279    time: 58.8350  last_time: 29.9197  data_time: 0.0043  last_data_time: 0.0030   lr: 0.00073027  max_mem: 7672M
# [01/25 00:02:55 d2.utils.events]:  eta: 0:59:13  iter: 239  total_loss: 0.1991  loss_cls: 0.0469  loss_box_reg: 0.1471  loss_rpn_cls: 0.0002751  loss_rpn_loc: 0.002301    time: 57.8124  last_time: 26.9058  data_time: 0.0047  last_data_time: 0.0046   lr: 0.00079687  max_mem: 7672M
# [01/25 00:19:51 d2.utils.events]:  eta: 0:39:23  iter: 259  total_loss: 0.2049  loss_cls: 0.03868  loss_box_reg: 0.163  loss_rpn_cls: 9.797e-05  loss_rpn_loc: 0.001881    time: 57.2680  last_time: 40.6562  data_time: 0.0050  last_data_time: 0.0037   lr: 0.00086347  max_mem: 7672M
# [01/25 00:37:01 d2.utils.events]:  eta: 0:19:39  iter: 279  total_loss: 0.1881  loss_cls: 0.03418  loss_box_reg: 0.1479  loss_rpn_cls: 7.274e-05  loss_rpn_loc: 0.00163    time: 56.8521  last_time: 61.7485  data_time: 0.0039  last_data_time: 0.0050   lr: 0.00093007  max_mem: 7672M
# [01/25 00:53:17 d2.utils.events]:  eta: 0:00:00  iter: 299  total_loss: 0.1827  loss_cls: 0.03448  loss_box_reg: 0.1426  loss_rpn_cls: 0.0005194  loss_rpn_loc: 0.002224    time: 56.3091  last_time: 41.7227  data_time: 0.0042  last_data_time: 0.0035   lr: 0.00099667  max_mem: 7672M
# [01/25 00:53:17 d2.engine.hooks]: Overall training speed: 298 iterations in 4:39:40 (56.3091 s / it)
# [01/25 00:53:17 d2.engine.hooks]: Total training time: 4:39:59 (0:00:19 on hooks)
# WARNING [01/25 00:53:17 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/25 00:53:17 d2.data.datasets.coco]: Loaded 40 images in COCO format from ../DatasetMouse/Computer mouse/valid/_annotations.coco.json
# [01/25 00:53:18 d2.data.build]: Distribution of instances among all 2 categories:
# |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|
# | Computer-mo.. | 0            | Computer-mo.. | 44           |
# |               |              |               |              |
# |     total     | 44           |               |              |
# [01/25 00:53:18 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [01/25 00:53:18 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/25 00:53:18 d2.data.common]: Serializing 40 elements to byte tensors and concatenating them all ...
# [01/25 00:53:18 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [01/25 00:53:18 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [01/25 00:53:18 d2.evaluation.evaluator]: Start inference on 40 batches
# [01/25 00:53:54 d2.evaluation.evaluator]: Inference done 11/40. Dataloading: 0.0006 s/iter. Inference: 2.6994 s/iter. Eval: 0.0004 s/iter. Total: 2.7005 s/iter. ETA=0:01:18
# [01/25 00:53:59 d2.evaluation.evaluator]: Inference done 13/40. Dataloading: 0.0008 s/iter. Inference: 2.6818 s/iter. Eval: 0.0004 s/iter. Total: 2.6831 s/iter. ETA=0:01:12
# [01/25 00:54:04 d2.evaluation.evaluator]: Inference done 15/40. Dataloading: 0.0009 s/iter. Inference: 2.6641 s/iter. Eval: 0.0004 s/iter. Total: 2.6657 s/iter. ETA=0:01:06
# [01/25 00:54:09 d2.evaluation.evaluator]: Inference done 17/40. Dataloading: 0.0009 s/iter. Inference: 2.6410 s/iter. Eval: 0.0004 s/iter. Total: 2.6425 s/iter. ETA=0:01:00
# [01/25 00:54:14 d2.evaluation.evaluator]: Inference done 19/40. Dataloading: 0.0009 s/iter. Inference: 2.6367 s/iter. Eval: 0.0005 s/iter. Total: 2.6384 s/iter. ETA=0:00:55
# [01/25 00:54:20 d2.evaluation.evaluator]: Inference done 21/40. Dataloading: 0.0010 s/iter. Inference: 2.6421 s/iter. Eval: 0.0004 s/iter. Total: 2.6438 s/iter. ETA=0:00:50
# [01/25 00:54:25 d2.evaluation.evaluator]: Inference done 23/40. Dataloading: 0.0009 s/iter. Inference: 2.6399 s/iter. Eval: 0.0004 s/iter. Total: 2.6416 s/iter. ETA=0:00:44
# [01/25 00:54:30 d2.evaluation.evaluator]: Inference done 25/40. Dataloading: 0.0009 s/iter. Inference: 2.6295 s/iter. Eval: 0.0005 s/iter. Total: 2.6313 s/iter. ETA=0:00:39
# [01/25 00:54:35 d2.evaluation.evaluator]: Inference done 27/40. Dataloading: 0.0010 s/iter. Inference: 2.6320 s/iter. Eval: 0.0005 s/iter. Total: 2.6338 s/iter. ETA=0:00:34
# [01/25 00:54:40 d2.evaluation.evaluator]: Inference done 29/40. Dataloading: 0.0010 s/iter. Inference: 2.6247 s/iter. Eval: 0.0005 s/iter. Total: 2.6265 s/iter. ETA=0:00:28
# [01/25 00:54:46 d2.evaluation.evaluator]: Inference done 31/40. Dataloading: 0.0011 s/iter. Inference: 2.6320 s/iter. Eval: 0.0004 s/iter. Total: 2.6339 s/iter. ETA=0:00:23
# [01/25 00:54:51 d2.evaluation.evaluator]: Inference done 33/40. Dataloading: 0.0011 s/iter. Inference: 2.6382 s/iter. Eval: 0.0004 s/iter. Total: 2.6401 s/iter. ETA=0:00:18
# [01/25 00:54:57 d2.evaluation.evaluator]: Inference done 35/40. Dataloading: 0.0011 s/iter. Inference: 2.6460 s/iter. Eval: 0.0004 s/iter. Total: 2.6479 s/iter. ETA=0:00:13
# [01/25 00:55:02 d2.evaluation.evaluator]: Inference done 37/40. Dataloading: 0.0011 s/iter. Inference: 2.6468 s/iter. Eval: 0.0004 s/iter. Total: 2.6487 s/iter. ETA=0:00:07
# [01/25 00:55:08 d2.evaluation.evaluator]: Inference done 39/40. Dataloading: 0.0011 s/iter. Inference: 2.6502 s/iter. Eval: 0.0004 s/iter. Total: 2.6522 s/iter. ETA=0:00:02
# [01/25 00:55:11 d2.evaluation.evaluator]: Total inference time: 0:01:33.940897 (2.684026 s / iter per device, on 1 devices)
# [01/25 00:55:11 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:32 (2.653345 s / iter per device, on 1 devices)
# [01/25 00:55:11 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 35
#      33 trainer = CocoTrainer(cfg)
#      34 trainer.resume_or_load(resume=False)
# ---> 35 trainer.train()
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\defaults.py:486, in DefaultTrainer.train(self)
#     479 def train(self):
#     480     """
#     481     Run training.
#     482
#     483     Returns:
#     484         OrderedDict of results, if evaluation is enabled. Otherwise None.
#     485     """
# --> 486     super().train(self.start_iter, self.max_iter)
#     487     if len(self.cfg.TEST.EXPECTED_RESULTS) and comm.is_main_process():
#     488         assert hasattr(
#     489             self, "_last_eval_results"
#     490         ), "No evaluation results obtained during training!"
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\train_loop.py:165, in TrainerBase.train(self, start_iter, max_iter)
#     163     raise
#     164 finally:
# --> 165     self.after_train()
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\train_loop.py:174, in TrainerBase.after_train(self)
#     172 self.storage.iter = self.iter
#     173 for h in self._hooks:
# --> 174     h.after_train()
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\hooks.py:561, in EvalHook.after_train(self)
#     558 def after_train(self):
#     559     # This condition is to prevent the eval from running after a failed training
#     560     if self._eval_after_train and self.trainer.iter + 1 >= self.trainer.max_iter:
# --> 561         self._do_eval()
#     562     # func is likely a closure that holds reference to the trainer
#     563     # therefore we clean it to avoid circular reference in the end
#     564     del self._func
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\hooks.py:529, in EvalHook._do_eval(self)
#     528 def _do_eval(self):
# --> 529     results = self._func()
#     531     if results:
#     532         assert isinstance(
#     533             results, dict
#     534         ), "Eval function must return a dict. Got {} instead.".format(results)
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\defaults.py:455, in DefaultTrainer.build_hooks.<locals>.test_and_save_results()
#     454 def test_and_save_results():
# --> 455     self._last_eval_results = self.test(self.cfg, self.model)
#     456     return self._last_eval_results
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\engine\defaults.py:619, in DefaultTrainer.test(cls, cfg, model, evaluators)
#     617         results[dataset_name] = {}
#     618         continue
# --> 619 results_i = inference_on_dataset(model, data_loader, evaluator)
#     620 results[dataset_name] = results_i
#     621 if comm.is_main_process():
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\evaluation\evaluator.py:213, in inference_on_dataset(model, data_loader, evaluator, callbacks)
#     206 total_compute_time_str = str(datetime.timedelta(seconds=int(total_compute_time)))
#     207 logger.info(
#     208     "Total inference pure compute time: {} ({:.6f} s / iter per device, on {} devices)".format(
#     209         total_compute_time_str, total_compute_time / (total - num_warmup), num_devices
#     210     )
#     211 )
# --> 213 results = evaluator.evaluate()
#     214 # An evaluator may return None when not in main process.
#     215 # Replace it by an empty dict instead to make it easier for downstream code to handle
#     216 if results is None:
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\evaluation\coco_evaluation.py:206, in COCOEvaluator.evaluate(self, img_ids)
#     204     self._eval_box_proposals(predictions)
#     205 if "instances" in predictions[0]:
# --> 206     self._eval_predictions(predictions, img_ids=img_ids)
#     207 # Copy so the caller can do whatever with results
#     208 return copy.deepcopy(self._results)
#
# File b:\arquivos\documentos ricardo\projetos python\prova ia\detectron2\detectron2\evaluation\coco_evaluation.py:240, in COCOEvaluator._eval_predictions(self, predictions, img_ids)
#     238     for result in coco_results:
#     239         category_id = result["category_id"]
# --> 240         assert category_id < num_classes, (
#     241             f"A prediction has class={category_id}, "
#     242             f"but the dataset only has {num_classes} classes and "
#     243             f"predicted class id should be in [0, {num_classes - 1}]."
#     244         )
#     245         result["category_id"] = reverse_id_mapping[category_id]
#     247 if self._output_dir:
#
# AssertionError: A prediction has class=2, but the dataset only has 2 classes and predicted class id should be in [0, 1].

# %%
#test evaluation
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.85
predictor = DefaultPredictor(cfg)
evaluator = COCOEvaluator("my_dataset_test", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "my_dataset_test")
inference_on_dataset(trainer.model, val_loader, evaluator)
# Out:
# [01/25 01:35:56 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output\model_final.pth ...
# WARNING [01/25 01:35:57 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [01/25 01:35:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/25 01:35:57 d2.data.datasets.coco]: Loaded 20 images in COCO format from ../DatasetMouse/Computer mouse/test/_annotations.coco.json
# [01/25 01:35:57 d2.data.build]: Distribution of instances among all 2 categories:
# |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|
# | Computer-mo.. | 0            | Computer-mo.. | 22           |
# |               |              |               |              |
# |     total     | 22           |               |              |
# [01/25 01:35:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [01/25 01:35:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/25 01:35:57 d2.data.common]: Serializing 20 elements to byte tensors and concatenating them all ...
# [01/25 01:35:57 d2.data.common]: Serialized dataset takes 0.01 MiB
# [01/25 01:35:57 d2.evaluation.evaluator]: Start inference on 20 batches
# [01/25 01:36:10 d2.evaluation.evaluator]: Inference done 1/20. Dataloading: 7.2736 s/iter. Inference: 5.6377 s/iter. Eval: 0.0010 s/iter. Total: 12.9195 s/iter. ETA=0:04:05
# [01/25 01:36:16 d2.evaluation.evaluator]: Inference done 2/20. Dataloading: 3.6371 s/iter. Inference: 5.6511 s/iter. Eval: 0.0007 s/iter. Total: 9.2930 s/iter. ETA=0:02:47
# [01/25 01:36:22 d2.evaluation.evaluator]: Inference done 3/20. Dataloading: 2.4251 s/iter. Inference: 5.6312 s/iter. Eval: 0.0005 s/iter. Total: 8.0599 s/iter. ETA=0:02:17
# [01/25 01:36:27 d2.evaluation.evaluator]: Inference done 4/20. Dataloading: 1.8191 s/iter. Inference: 5.6315 s/iter. Eval: 0.0006 s/iter. Total: 7.4536 s/iter. ETA=0:01:59
# [01/25 01:36:33 d2.evaluation.evaluator]: Inference done 5/20. Dataloading: 1.4558 s/iter. Inference: 5.6253 s/iter. Eval: 0.0005 s/iter. Total: 7.0837 s/iter. ETA=0:01:46
# [01/25 01:36:38 d2.evaluation.evaluator]: Inference done 6/20. Dataloading: 0.0000 s/iter. Inference: 5.3837 s/iter. Eval: 0.0003 s/iter. Total: 5.3840 s/iter. ETA=0:01:15
# [01/25 01:36:44 d2.evaluation.evaluator]: Inference done 7/20. Dataloading: 0.0012 s/iter. Inference: 5.4469 s/iter. Eval: 0.0003 s/iter. Total: 5.4487 s/iter. ETA=0:01:10
# [01/25 01:36:49 d2.evaluation.evaluator]: Inference done 8/20. Dataloading: 0.0012 s/iter. Inference: 5.4899 s/iter. Eval: 0.0003 s/iter. Total: 5.4919 s/iter. ETA=0:01:05
# [01/25 01:36:55 d2.evaluation.evaluator]: Inference done 9/20. Dataloading: 0.0011 s/iter. Inference: 5.5194 s/iter. Eval: 0.0003 s/iter. Total: 5.5214 s/iter. ETA=0:01:00
# [01/25 01:37:00 d2.evaluation.evaluator]: Inference done 10/20. Dataloading: 0.0011 s/iter. Inference: 5.5275 s/iter. Eval: 0.0003 s/iter. Total: 5.5295 s/iter. ETA=0:00:55
# [01/25 01:37:06 d2.evaluation.evaluator]: Inference done 11/20. Dataloading: 0.0011 s/iter. Inference: 5.5405 s/iter. Eval: 0.0003 s/iter. Total: 5.5424 s/iter. ETA=0:00:49
# [01/25 01:37:12 d2.evaluation.evaluator]: Inference done 12/20. Dataloading: 0.0011 s/iter. Inference: 5.5476 s/iter. Eval: 0.0003 s/iter. Total: 5.5497 s/iter. ETA=0:00:44
# [01/25 01:37:17 d2.evaluation.evaluator]: Inference done 13/20. Dataloading: 0.0011 s/iter. Inference: 5.5540 s/iter. Eval: 0.0003 s/iter. Total: 5.5562 s/iter. ETA=0:00:38
# [01/25 01:37:23 d2.evaluation.evaluator]: Inference done 14/20. Dataloading: 0.0011 s/iter. Inference: 5.5591 s/iter. Eval: 0.0003 s/iter. Total: 5.5612 s/iter. ETA=0:00:33
# [01/25 01:37:28 d2.evaluation.evaluator]: Inference done 15/20. Dataloading: 0.0011 s/iter. Inference: 5.5608 s/iter. Eval: 0.0003 s/iter. Total: 5.5629 s/iter. ETA=0:00:27
# [01/25 01:37:34 d2.evaluation.evaluator]: Inference done 16/20. Dataloading: 0.0011 s/iter. Inference: 5.5518 s/iter. Eval: 0.0003 s/iter. Total: 5.5539 s/iter. ETA=0:00:22
# [01/25 01:37:39 d2.evaluation.evaluator]: Inference done 17/20. Dataloading: 0.0012 s/iter. Inference: 5.5456 s/iter. Eval: 0.0003 s/iter. Total: 5.5478 s/iter. ETA=0:00:16
# [01/25 01:37:45 d2.evaluation.evaluator]: Inference done 18/20. Dataloading: 0.0012 s/iter. Inference: 5.5409 s/iter. Eval: 0.0003 s/iter. Total: 5.5431 s/iter. ETA=0:00:11
# [01/25 01:37:50 d2.evaluation.evaluator]: Inference done 19/20. Dataloading: 0.0012 s/iter. Inference: 5.5363 s/iter. Eval: 0.0003 s/iter. Total: 5.5385 s/iter. ETA=0:00:05
# [01/25 01:37:56 d2.evaluation.evaluator]: Inference done 20/20. Dataloading: 0.0012 s/iter. Inference: 5.5312 s/iter. Eval: 0.0003 s/iter. Total: 5.5335 s/iter. ETA=0:00:00
# [01/25 01:37:57 d2.evaluation.evaluator]: Total inference time: 0:01:23.670158 (5.578011 s / iter per device, on 1 devices)
# [01/25 01:37:57 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:22 (5.531158 s / iter per device, on 1 devices)
# [01/25 01:37:57 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [01/25 01:37:57 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [01/25 01:37:57 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [01/25 01:37:57 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [01/25 01:37:57 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [01/25 01:37:57 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [01/25 01:37:57 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.623
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.812
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.738
# [01/25 01:37:57 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 62.298 | 81.218 | 66.894 | 20.000 | 54.212 | 72.030 |
# [01/25 01:37:57 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category       | AP   | category       | AP     |
# |:---------------|:-----|:---------------|:-------|
# | Computer-mouse | nan  | Computer-mouse | 62.298 |
# OrderedDict([('bbox',
#               {'AP': 62.298378922673756,
#                'AP50': 81.21796382934997,
#                'AP75': 66.89356435643565,
#                'APs': 20.0,
#                'APm': 54.21219180741603,
#                'APl': 72.02970297029702,
#                'AP-Computer-mouse': 62.298378922673756})])

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.DATASETS.TEST = ("my_dataset_test", )
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
predictor = DefaultPredictor(cfg)
test_metadata = MetadataCatalog.get("my_dataset_test")
# Out:
# [01/25 01:42:48 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output\model_final.pth ...

# %%
from detectron2.utils.visualizer import ColorMode
import glob

for imageName in glob.glob('../DatasetMouse/Computer mouse/test/*jpg'):
  im = cv2.imread(imageName)
  outputs = predictor(im)
  v = Visualizer(im[:, :, ::-1],
              metadata=test_metadata,
              scale=0.8
                )
  out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  plt.imshow(out.get_image()[:, :, ::-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       7 v = Visualizer(im[:, :, ::-1],
#       8             metadata=test_metadata,
#       9             scale=0.8
#      10               )
#      11 out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
# ---> 12 plt.imshow(out.get_image()[:, :, ::-2])
#
# File b:\Programas\Anaconda\envs\prova\lib\site-packages\matplotlib\pyplot.py:3343, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3322 @_copy_docstring_and_deprecators(Axes.imshow)
#    3323 def imshow(
#    3324     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3341     **kwargs,
#    3342 ) -> AxesImage:
# -> 3343     __ret = gca().imshow(
#    3344         X,
#    3345         cmap=cmap,
#    3346         norm=norm,
#    3347         aspect=aspect,
#    3348         interpolation=interpolation,
#    3349         alpha=alpha,
#    3350         vmin=vmin,
#    3351         vmax=vmax,
#    3352         origin=origin,
#    3353         extent=extent,
#    3354         interpolation_stage=interpolation_stage,
#    3355         filternorm=filternorm,
#    3356         filterrad=filterrad,
#    3357         resample=resample,
#    3358         url=url,
#    3359         **({"data": data} if data is not None else {}),
#    3360         **kwargs,
#    3361     )
#    3362     sci(__ret)
#    3363     return __ret
#
# File b:\Programas\Anaconda\envs\prova\lib\site-packages\matplotlib\__init__.py:1492, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1489 @functools.wraps(func)
#    1490 def inner(ax, *args, data=None, **kwargs):
#    1491     if data is None:
# -> 1492         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1494     bound = new_sig.bind(ax, *args, **kwargs)
#    1495     auto_label = (bound.arguments.get(label_namer)
#    1496                   or bound.kwargs.get(label_namer))
#
# File b:\Programas\Anaconda\envs\prova\lib\site-packages\matplotlib\axes\_axes.py:5756, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5753 if aspect is not None:
#    5754     self.set_aspect(aspect)
# -> 5756 im.set_data(X)
#    5757 im.set_alpha(alpha)
#    5758 if im.get_clip_path() is None:
#    5759     # image does not already have clipping set, clip to axes patch
#
# File b:\Programas\Anaconda\envs\prova\lib\site-packages\matplotlib\image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File b:\Programas\Anaconda\envs\prova\lib\site-packages\matplotlib\image.py:693, in _ImageBase._normalize_image_array(A)
#     691     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     692 if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 693     raise TypeError(f"Invalid shape {A.shape} for image data")
#     694 if A.ndim == 3:
#     695     # If the input data has values outside the valid range (after
#     696     # normalisation), we issue a warning and then clip X to the bounds
#     697     # - otherwise casting wraps extreme values, hiding outliers and
#     698     # making reliable interpretation impossible.
#     699     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (332, 332, 2) for image data
